# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# **Data Cleaning and Preparation :**

# %%
# Import dataset and read

data = pd.read_csv('Cardiotocographic.csv')
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Extract necessary data

df = data.iloc[:,:11]
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV
# 0      0.5  43.000000   2.4
# 1      2.1   0.000000  10.4
# ...

# %%
# Analyse data
df.head(10)
# Out:
#            LB        AC   FM        UC        DL   DS        DP  ASTV  MSTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  73.0   0.5
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.000000  17.0   2.1
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.000000  16.0   2.1
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.000000  16.0   2.4
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.000000  16.0   2.4
# 5  134.000000  0.001116  0.0  0.010493  0.009444  0.0  0.002099  26.0   5.9
# 6  134.000000  0.001403  0.0  0.012623  0.008415  0.0  0.002805  29.0   6.3
# 7  122.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  83.0   0.5
# 8  122.000000  0.038567  0.0  0.001517  0.000000  0.0  0.000000  84.0   0.5
# 9  122.000000  0.000000  0.0  0.002967  0.000000  0.0  0.000000  86.0   0.3
#
#    ALTV  MLTV
# 0  43.0   2.4
# 1   0.0  10.4
# 2   0.0  13.4
# 3   0.0  23.0
# 4   0.0  19.9
# 5   0.0   0.0
# 6   0.0   0.0
# ...

# %%
df.tail(10)
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# 2116  140.0  0.003968  0.000000  0.003968  0.000000  0.0  0.0  80.0   0.2
# 2117  140.0  0.000000  0.000000  0.007812  0.000000  0.0  0.0  79.0   0.3
# 2118  140.0  0.000000  0.000000  0.006470  0.000898  0.0  0.0  79.0   0.5
# 2119  140.0  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0   0.6
# 2120  140.0  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0   0.7
# 2121  140.0  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV
# 2116  36.000000   2.2
# 2117  20.000000   8.5
# 2118  26.428179   7.0
# 2119  27.000000   6.4
# 2120  17.000000   6.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# LB      float64
# AC      float64
# FM      float64
# UC      float64
# DL      float64
# DS      float64
# DP      float64
# ASTV    float64
# MSTV    float64
# ALTV    float64
# MLTV    float64
# dtype: object

# %%
df.shape
# Out:
# (2126, 11)

# %%
df.size
# Out:
# 23386

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LB      2105 non-null   float64
#  1   AC      2106 non-null   float64
#  2   FM      2126 non-null   float64
#  3   UC      2126 non-null   float64
#  4   DL      2126 non-null   float64
#  5   DS      2105 non-null   float64
#  6   DP      2105 non-null   float64
#  7   ASTV    2126 non-null   float64
#  8   MSTV    2126 non-null   float64
#  9   ALTV    2126 non-null   float64
#  10  MLTV    2105 non-null   float64
# dtypes: float64(11)
# memory usage: 182.8 KB

# %%
df.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV
# 0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
df.isnull().sum()
# Out:
# LB      21
# AC      20
# FM       0
# UC       0
# DL       0
# DS      21
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
# Fill null values with mean

df.fillna(df.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# LB      0
# AC      0
# FM      0
# UC      0
# DL      0
# DS      0
# DP      0
# ASTV    0
# MSTV    0
# ALTV    0
# MLTV    0
# dtype: int64

# %%
# Check duplicate values

df.duplicated().sum()
# Out:
# 5

# %%
df[df.duplicated()]
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 68    140.0  0.007278  0.000000  0.004367  0.000000  0.0  0.000000  34.0
# 791   123.0  0.002660  0.003989  0.000000  0.000000  0.0  0.000000  50.0
# 1115  122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  19.0
# 1381  121.0  0.000000  0.000000  0.003478  0.005217  0.0  0.001739  24.0
# 1458  148.0  0.004717  0.000000  0.002358  0.000000  0.0  0.000000  40.0
#
#       MSTV  ALTV  MLTV
# 68     1.2   0.0  10.3
# 791    0.9   4.0  14.8
# 1115   1.9   0.0  15.1
# 1381   1.5   0.0   0.0
# 1458   0.9   0.0  10.6

# %%
df1 = df.drop_duplicates()

# %%
df1.shape
# Out:
# (2121, 11)

# %% [markdown]
# **Statistical Summary :**

# %%
df1.mean()
# Out:
# LB      133.349595
# AC        0.003220
# FM        0.009916
# UC        0.004396
# DL        0.001897
# DS        0.000003
# DP        0.000175
# ASTV     47.028035
# MSTV      1.364577
# ALTV     10.308326
# MLTV      8.280467
# dtype: float64

# %%
df1.median()
# Out:
# LB      133.000000
# AC        0.001668
# FM        0.000000
# UC        0.004505
# DL        0.000000
# DS        0.000000
# DP        0.000000
# ASTV     49.000000
# MSTV      1.200000
# ALTV      0.000000
# MLTV      7.500000
# dtype: float64

# %%
df1.std()
# Out:
# LB      11.213941
# AC       0.004373
# FM       0.067618
# UC       0.003341
# DL       0.003345
# DS       0.000141
# DP       0.000836
# ASTV    18.816833
# MSTV     1.174862
# ALTV    21.224880
# MLTV     7.738383
# dtype: float64

# %%
df1.var()
# Out:
# LB      1.257525e+02
# AC      1.912372e-05
# FM      4.572165e-03
# UC      1.116445e-05
# DL      1.118789e-05
# DS      1.988109e-08
# DP      6.986817e-07
# ASTV    3.540732e+02
# MSTV    1.380301e+00
# ALTV    4.504955e+02
# MLTV    5.988257e+01
# dtype: float64

# %%
summary = df1.describe()
summary
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2121.000000  2121.000000  2121.000000  2121.000000  2121.000000
# mean    133.349595     0.003220     0.009916     0.004396     0.001897
# std      11.213941     0.004373     0.067618     0.003341     0.003345
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001862     0.000000
# 50%     133.000000     0.001668     0.000000     0.004505     0.000000
# 75%     140.000000     0.005610     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2121.000000  2121.000000  2121.000000  2121.000000  2121.000000
# mean      0.000003     0.000175    47.028035     1.364577    10.308326
# std       0.000141     0.000836    18.816833     1.174862    21.224880
# ...

# %% [markdown]
# **Data Visualization :**

# %%
# Histogram

df1.hist(bins = 10 , figsize = (15,10) , color='skyblue')
# Out:
# array([[<Axes: title={'center': 'LB'}>, <Axes: title={'center': 'AC'}>,
#         <Axes: title={'center': 'FM'}>],
#        [<Axes: title={'center': 'UC'}>, <Axes: title={'center': 'DL'}>,
#         <Axes: title={'center': 'DS'}>],
#        [<Axes: title={'center': 'DP'}>, <Axes: title={'center': 'ASTV'}>,
#         <Axes: title={'center': 'MSTV'}>],
#        [<Axes: title={'center': 'ALTV'}>,
#         <Axes: title={'center': 'MLTV'}>, <Axes: >]], dtype=object)

# %%
# Finding skewness & variance

# %%
df1.skew()
# Out:
# LB      0.321866
# AC      2.026439
# FM      6.744635
# UC      0.973064
# DL      2.009334
# DS      8.450758
# DP      6.461961
# ASTV    0.053458
# MSTV    4.138777
# ALTV    2.976929
# MLTV    3.563549
# dtype: float64

# %%
df1.var()
# Out:
# LB      1.257525e+02
# AC      1.912372e-05
# FM      4.572165e-03
# UC      1.116445e-05
# DL      1.118789e-05
# DS      1.988109e-08
# DP      6.986817e-07
# ASTV    3.540732e+02
# MSTV    1.380301e+00
# ALTV    4.504955e+02
# MLTV    5.988257e+01
# dtype: float64

# %%
# Box plots

plt.figure(figsize=(10,5))
sn.boxplot(data=df1)
plt.show()

# %%
# Generating heatmaps for finding correlation

sn.heatmap(df1)
# Out:
# <Axes: >

# %%
# Pairplot

sn.pairplot(df1)
plt.show()

# %% [markdown]
# **Pattern Recognition and Insights :**

# %%
correlation = df1.corr()
print("Correlation matrix : \n", correlation)
# Out:
# Correlation matrix :
#              LB        AC        FM        UC        DL        DS        DP  \
# LB    1.000000 -0.064206  0.018746 -0.167521 -0.126251 -0.005454 -0.046855
# AC   -0.064206  1.000000  0.009418  0.071435 -0.092838 -0.033120 -0.082700
# FM    0.018746  0.009418  1.000000 -0.053483  0.009651  0.029894  0.121459
# UC   -0.167521  0.071435 -0.053483  1.000000  0.189665 -0.006958  0.070549
# DL   -0.126251 -0.092838  0.009651  0.189665  1.000000  0.058450  0.144043
# DS   -0.005454 -0.033120  0.029894 -0.006958  0.058450  1.000000  0.004297
# DP   -0.046855 -0.082700  0.121459  0.070549  0.144043  0.004297  1.000000
# ASTV  0.241545 -0.231357 -0.032980 -0.182606 -0.069537  0.008403  0.039032
# MSTV -0.169400  0.134031  0.017044  0.189543  0.410194  0.016076  0.119221
# ALTV  0.210575 -0.271304 -0.012086 -0.228257 -0.187353 -0.004412 -0.077485
# MLTV -0.003490 -0.105173 -0.006181 -0.048411 -0.164283  0.034382 -0.113088
#
#           ASTV      MSTV      ALTV      MLTV
# ...

# %% [markdown]
# **Conclusion :**

# %% [markdown]
# Performed EDA on the given dataset to uncover insights, identify patterns, and understand the dataset's underlying structure.Data contains various variables related to feteral heart rate monitoring.Imported dataset then cleaned data and prepared.  Statistical summary reveals basic stats of data for each variable.Visualization tools like histogram,box plot,heatmap and pair plot shows the data visually and better to understand variables and their relationships.
